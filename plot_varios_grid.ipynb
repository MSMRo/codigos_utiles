# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
path = "/kaggle/input/cap-sleep-unbalanced-dataset/Balanced Data/Balanced Data"

path_ls = os.listdir(path)
path_ls
# Out:
# ['bal_all.csv',
#  'bal_healthy_F4C4.csv',
#  'bal_nfle.csv',
#  'bal_ins.csv',
#  'bal_plm.csv',
#  'bal_sdb.csv',
#  'bal_healthy.csv',
#  'bal_rbd.csv',
#  'bal_narco.csv']

# %% [markdown]
# ## Lectura de los csv

# %%
df1 = pd.read_csv(path + '/'+path_ls[0], header=None)
df1.head()
# Out:
#         0          1          2          3          4          5     \
# 0 -17.231380 -16.712454 -15.949328 -14.087302 -11.065324  -7.982295
# 1   9.020147   8.470696   6.456044   4.410867   2.029915  -1.510989
# 2  -8.379121  -8.134921  -8.165446  -8.989621 -10.576923 -11.920024
# 3   4.929792   4.166667   2.457265  -0.656288  -3.403541  -3.800366
# 4  -6.181319  -6.486569  -5.204518  -3.556166  -1.968864  -1.388889
#
#         6          7          8          9     ...       1015       1016  \
# 0  -5.509768  -3.769841  -3.037241  -3.495116  ...   0.473138   0.167888
# 1  -4.990842  -6.669719  -6.456044  -5.479243  ...  -3.830891  -3.556166
# 2 -12.713675 -13.324176 -13.202076 -12.225275  ...  10.393773  11.156899
# 3  -2.945665  -2.274115  -2.182540  -2.670940  ...  14.300977  12.835775
# 4  -2.029915  -2.823565  -3.342491  -3.952991  ...  -4.410867  -3.678266
#
#         1017       1018       1019      1020      1021      1022      1023  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10962 entries, 0 to 10961
# Columns: 1025 entries, 0 to 1024
# dtypes: float64(1025)
# memory usage: 85.7 MB

# %%
nfig = 15
# nrows x ncols = nfig
nrows = 5
ncols = 3

fig, ax = plt.subplots(nrows=nrows, ncols=ncols ,figsize=(10,10))
fig.suptitle(f"{path_ls[0]}", fontsize=18)
fig.tight_layout()

for n in range(nfig):
    row = n//ncols
    col = n%ncols
    
    ax[row,col].plot(df1.iloc[n,:-1])
    ax[row,col].grid(ls=":")
    ax[row,col].set_ylim(-50,50)

# %%
def group_plot(nfig, nrows, ncols, df_array,title_plot="titulo xxx", ylim1=-10, ylim2=10):
    
    if nrows*ncols != nfig:
        raise "Error: nrows*ncols != nfig"


    fig, ax = plt.subplots(nrows=nrows, ncols=ncols ,figsize=(10,10))
    fig.suptitle(f"{title_plot}", fontsize=18)
    fig.tight_layout()

    for n in range(nfig):
        row = n//ncols
        col = n%ncols

        ax[row,col].plot(df_array.iloc[n,:])
        ax[row,col].grid(ls=":")
        ax[row,col].set_ylim(ylim1,ylim2)

# %%
group_plot(15,5,3,df1.iloc[100:115,:-1], title_plot="100:115", ylim1=-50, ylim2=50)
